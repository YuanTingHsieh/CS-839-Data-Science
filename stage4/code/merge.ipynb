# %%
import pandas as pd
import os
import py_entitymatching as em
import numpy as np

datasets_dir = os.getcwd() + os.sep

pathA = datasets_dir + "/data/imdb_clean.csv"
pathB = datasets_dir + "/data/tomato_clean.csv"
pathC = datasets_dir + "/data/block.csv"

A = pd.read_csv(pathA)
B = pd.read_csv(pathB)
# Rename first empty attr 
# df.rename(columns={"Unnamed: 0": "id"},  inplace=True)

p_A = A[['movie_no', 'movie_name', 'movie_year', 'movie_director', 'movie_star']]
p_B = B[['movie_no', 'movie_name', 'movie_year', 'movie_director', 'movie_star']]

em.set_key(p_A, 'movie_no')
em.set_key(p_B, 'movie_no')

pathS = datasets_dir + "/data/labeled_data.csv"

S = em.read_csv_metadata(pathS, 
                         key='_id',
                         ltable=p_A, rtable=p_B, 
                         fk_ltable='ltable_movie_no', fk_rtable='rtable_movie_no')

IJ = em.split_train_test(S, train_proportion=0.7, random_state=0)
I = IJ['train']
J = IJ['test']

# %%
# Classifier
dt = em.DTMatcher(name='DecisionTree', random_state=0)
svm = em.SVMMatcher(name='SVM', random_state=0)
rf = em.RFMatcher(name='RF', random_state=0)
lg = em.LogRegMatcher(name='LogReg', random_state=0)
ln = em.LinRegMatcher(name='LinReg')
nb = em.NBMatcher(name='NB')

# %%
# Feature generation
F = em.get_features_for_matching(p_A, p_B, validate_inferred_attr_types=False)

H = em.extract_feature_vecs(I, 
                            feature_table=F, 
                            attrs_after='label',
                            show_progress=False)

# Missing value
H = em.impute_table(H, 
                exclude_attrs=['_id', 'ltable_movie_no', 'rtable_movie_no', 'label'],
                strategy='mean')

# %%
# Corss Validation 
result = em.select_matcher([dt, rf, svm, ln, lg, nb], table=H, 
        exclude_attrs=['_id', 'ltable_movie_no', 'rtable_movie_no', 'label'],
        k=5, # Num of fold
        target_attr='label', metric_to_select_matcher='f1', random_state=0)

# %%
# Apply to testing set

fc = result['selected_matcher'] # LinReg here
# dt = em.DTMatcher(name='DT', random_state=0)

fc.fit(table=H, 
       exclude_attrs=['_id', 'ltable_movie_no', 'rtable_movie_no', 'label'], 
       target_attr='label')

L = em.extract_feature_vecs(J, feature_table=F,
                            attrs_after='label', show_progress=False)

predictions = fc.predict(table=L, exclude_attrs=['_id', 'ltable_movie_no', 'rtable_movie_no', 'label'], 
              append=True, target_attr='predicted', inplace=False)

eval_result = em.eval_matches(predictions, 'label', 'predicted')
em.print_eval_summary(eval_result)
# Out:
# Precision : 98.18% (54/55)
# Recall : 96.43% (54/56)
# F1 : 97.3%
# False positives : 1 (out of 55 positive predictions)
# False negatives : 2 (out of 98 negative predictions)

# %%
# C is the blokced data 
C = em.read_csv_metadata(pathC,
                        key='_id',
                        ltable=p_A, rtable=p_B,
                        fk_ltable='ltable_movie_no', fk_rtable='rtable_movie_no')

cl = result['selected_matcher']

L = em.extract_feature_vecs(C, feature_table=F,
                            show_progress=False)


predictions = cl.predict(table=L, exclude_attrs=['_id', 'ltable_movie_no', 'rtable_movie_no'], 
              append=True, target_attr='predicted', probs_attr='score', return_probs = True, inplace=False)

# %%
# Tuple predicted as match
tn = predictions[(predictions['predicted'] == 1)]
C[C['_id'].isin(tn['_id'])]
# Out:
#          _id  ltable_movie_no  rtable_movie_no  \
# 0        106             1454                1
# 3       3391             2450                6
# 4       4410             2917                9
# 5       5260              135               13
# 7       6113              306               17
# 21      7832             1042               21
# 22      7940              172               22
# 23      8193             2712               23
# 24      8298             1792               24
# 25      8305             2244               25
# 26     10053              439               31
# 35     12124             1292               38
# 36     13052              427               45
# 37     14815              498               52
# 48     16564             2317               59
# 49     17722             2141               62
# 55     20364              720               69
# 56     20365             2827               70
# 57     20366              765               71
# 58     20422              864               75
# 59     20425              390               77
# 60     20481              543               82
# 61     20518              753               84
# 63     22427              208               91
# 64     22436              113               93
# 65     23364             1175               95
# 68     29026             2432              108
# 69     29027               13              109
# 71     29212             1800              115
# 72     29222             2468              116
# ...      ...              ...              ...
# 1865  746715             1945             2886
# 1866  751294             2581             2898
# 1876  754602             1823             2912
# 1883  755731             2952             2914
# 1884  755763              139             2917
# 1885  755764             2348             2918
# 1887  757542             2248             2923
# 1889  758376             1194             2924
# 1898  762336              324             2937
# 1899  763217             1500             2938
# 1900  763218              563             2939
# 1901  764569              361             2946
# 1908  765615              428             2952
# 1909  765616             2731             2953
# 1914  767302             1658             2956
# 1915  767323              803             2957
# 1919  770190             1477             2966
# 1920  770191             1781             2967
# 1921  770208             1569             2969
# 1922  770315             2349             2973
# 1925  771297             2289             2978
# 1926  771334             2360             2981
# 1927  771339              256             2982
# 1930  772188             1343             2983
# 1931  772226              657             2985
# 1932  772327              866             2986
# 1933  773268              818             2988
# 1935  774681              926             2995
# 1936  776139             2507             3003
# 1937  776141             1543             3004
#
#                        ltable_movie_name             ltable_movie_director  \
# 0                                  annie                        Will Gluck
# 3                             the family                        Luc Besson
# 4                      love beats rhymes                               RZA
# 5                              john wick      Chad Stahelski, David Leitch
# 7                           the revenant               Alejandro G. Irritu
# 21                       despicable me 2       Pierre Coffin, Chris Renaud
# 22    batman v superman: dawn of justice                       Zack Snyder
# 23                        a little chaos                      Alan Rickman
# 24                                  wild                   Jean-Marc Valle
# 25                          their finest                     Lone Scherfig
# 26            x-men: days of future past                      Bryan Singer
# 35                              criminal                      Ariel Vromen
# 36                               hangman                     Johnny Martin
# 37                   10 cloverfield lane                  Dan Trachtenberg
# 48                             draft day                      Ivan Reitman
# 49                     american pastoral                     Ewan McGregor
# 55                                  noah                  Darren Aronofsky
# 56                           suffragette                      Sarah Gavron
# 57                              snatched                   Jonathan Levine
# 58                          tomorrowland                         Brad Bird
# 59                                  life                   Daniel Espinosa
# 60                     london has fallen                      Babak Najafi
# 61                               newness                     Drake Doremus
# 63                            la la land                   Damien Chazelle
# 64                        doctor strange                  Scott Derrickson
# 65                            green room                   Jeremy Saulnier
# 68                              wheelman                       Jeremy Rush
# 69                        thor: ragnarok                     Taika Waititi
# 71                          ender's game                        Gavin Hood
# 72                            unfriended                   Levan Gabriadze
# ...                                  ...                               ...
# 1865                 inside llewyn davis             Ethan Coen, Joel Coen
# 1866          my big fat greek wedding 2                        Kirk Jones
# 1876                            the loft                     Erik Van Looy
# 1883                           the guest                      Adam Wingard
# 1884                             mother!                  Darren Aronofsky
# 1885                          misconduct                Shintaro Shimosawa
# 1887                 the limehouse golem                Juan Carlos Medina
# 1889                             inferno                        Ron Howard
# 5                              john wick      David Leitch, Chad Stahelski
# 7                           the revenant       Alejandro González Iñárritu
# 21                       despicable me 2       Pierre Coffin, Chris Renaud
# 22    batman v superman: dawn of justice                       Zack Snyder
# 23                        a little chaos                      Alan Rickman
# 24                                  wild                  Jean-Marc Vallée
# 25                          their finest                     Lone Scherfig
# 26            x-men: days of future past                      Bryan Singer
# 35                              criminal                      Ariel Vromen
# 36                               hangman                     Johnny Martin
# 37                   10 cloverfield lane                  Dan Trachtenberg
# 48                             draft day                      Ivan Reitman
# 49                     american pastoral                     Ewan McGregor
# 55                                  noah                  Darren Aronofsky
# 56                           suffragette                      Sarah Gavron
# 57                              snatched                   Jonathan Levine
# 58                          tomorrowland                         Brad Bird
# 59                                  life                   Daniel Espinosa
# 60                     london has fallen                      Babak Najafi
# 61                               newness                     Drake Doremus
# 63                            la la land                   Damien Chazelle
# 64                        doctor strange                  Scott Derrickson
# 65                            green room                   Jeremy Saulnier
# 68                              wheelman                       Jeremy Rush
# 69                        thor: ragnarok                     Taika Waititi
# 71                          ender's game                        Gavin Hood
# 72                            unfriended                   Levan Gabriadze
# ...                                  ...                               ...
# 1865                 inside llewyn davis             Ethan Coen, Joel Coen
# 1866          my big fat greek wedding 2                        Kirk Jones
# 1876                            the loft                     Erik Van Looy
# 1883                           the guest                      Adam Wingard
# 1884                             mother!                  Darren Aronofsky
# 1885                          misconduct                Shintaro Shimosawa
# 1887                 the limehouse golem                Juan Carlos Medina
# 1889                             inferno                        Ron Howard
# 1898                  ghost in the shell                    Rupert Sanders
# 1899                         leatherface  Julien Maury, Alexandre Bustillo
# 1900    mission: impossible rogue nation             Christopher McQuarrie
# 1901             in the heart of the sea                        Ron Howard
# 1908                           divergent                       Neil Burger
# 1909                          the gunman                      Pierre Morel
# 1914                          first kill                  Steven C. Miller
# 1915                                 spy                         Paul Feig
# 1919                            bushwick     Cary Murnion, Jonathan Milott
# 1920                         seventh son                     Sergey Bodrov
# 1921                               blame                    Quinn Shephard
# 1922                  the skeleton twins                     Craig Johnson
# 1925                                tusk                       Kevin Smith
# 1926              only lovers left alive                      Jim Jarmusch
# 1927                     the jungle book                       Jon Favreau
# 1930                      swiss army man     Daniel Scheinert, Daniel Kwan
# 1931                    12 years a slave                     Steve McQueen
# 1932         jack reacher: never go back                      Edward Zwick
# 1933                         knock knock                          Eli Roth
# 1935                        the shallows                Jaume Collet-Serra
# 1936                                  31                        Rob Zombie
# 1937                  let there be light                       Kevin Sorbo
#
#                                                                                         rtable_movie_star
# 0     Jamie Foxx, Rose Byrne, Bobby Cannavale, Cameron Diaz, Adewale Akinnuoye-Agbaje, David Zayas, Zo...
# 3           Robert De Niro, Michelle Pfeiffer, Tommy Lee Jones, Dianna Agron, John D'Leo, Kresh Novakovic
# 4     Azealia Banks, Jill Scott, Lucien Laviscount, Lorraine Toussaint, Hana Mae Lee, John David Washi...
# 5     Keanu Reeves, Michael Nyqvist, Alfie Allen, Adrianne Palicki, Bridget Moynahan, Dean Winters, Ia...
neel Sethi, Bill Murray, Ben Kingsley, Idris Elba, Lupita Nyong'o, Scarlett Johansso...
# 1930  Paul Dano, Daniel Radcliffe, Mary Elizabeth Winstead, Richard Gross, Timothy Eulich, Marika Cast...
# 1931  Chiwetel Ejiofor, Michael Fassbender, Benedict Cumberbatch, Paul Giamatti, Brad Pitt, Sarah Paul...
# 1932  Tom Cruise, Cobie Smulders, Danika Yarosh, Patrick Heusinger, Robert Knepper, Aldis Hodge, Holt ...
# 1933  Keanu Reeves, Lorenza Izzo, Ana de Armas, Aaron Burns, Ignacia Allamand, Colleen Camp, Dan Baily...
# 1935  Blake Lively, Oscar Jaenada, Sedona Legge, Brett Cullen, Angelo Josue, Lozano Corzo, José Manuel...
# 1936  Sheri Moon Zombie, Malcolm McDowell, Meg Foster, Elizabeth Daily, Sandra Rosko, Richard Brake, L...
# 1937                                 Kevin Sorbo, Sam Sorbo, Daniel Roebuck, Donielle Artese, Gary Grubbs
#
# [740 rows x 9 columns]

# %%
# Duplicate detect
dup_A = tn[tn["ltable_movie_no"].duplicated(keep=False)]
dup_B = tn[tn["rtable_movie_no"].duplicated(keep=False)]
# C[C['_id'].isin(dup_A['_id'])] 
# C[C['_id'].isin(dup_B['_id'])]

# %%
dup_T = pd.merge(dup_A, dup_B, how='outer', on=['_id','ltable_movie_no', 'rtable_movie_no'])
dup_T

# %%
# Remove duplicate
# clean_dup_A = tn["ltable_movie_no"].drop_duplicates(keep='first')
# clean_dup_B = tn["rtable_movie_no"].drop_duplicates(keep='first')
clean_dup_A = tn[~(tn["ltable_movie_no"].isin(dup_T['ltable_movie_no']))]
clean_dup_B = tn[~(tn["rtable_movie_no"].isin(dup_T['rtable_movie_no']))]
# clean_dup_B

# %%
# Remove all matched from A and B (A' and B')
new_A = A[(~A['movie_no'].isin(clean_dup_A['ltable_movie_no']))]
new_B = B[(~B['movie_no'].isin(clean_dup_B['rtable_movie_no']))]

# %%
# Select one pair of duplicate pairs
dict_A = {}
dict_B = {}

res = []
s_A = []
s_B = []
for index, row in dup_T.iterrows():
    if (row['ltable_movie_no'] not in dict_A) and (row['rtable_movie_no'] not in dict_B):
        dict_A[row['ltable_movie_no']] = 1
        dict_B[row['rtable_movie_no']] = 1
        s_A.append(row['ltable_movie_no'])
        s_B.append(row['rtable_movie_no'])
        res.append(row['_id'])

dict_RA = {}    
dict_RB = {}
for index, row in dup_T.iterrows():
    if (row['ltable_movie_no'] not in dict_A):
        dict_RA[row['ltable_movie_no']] = 1;
    if (row['rtable_movie_no'] not in dict_B):
        dict_RB[row['rtable_movie_no']] = 1;

# %%
dict_RB
rem_B = B[B['movie_no'].isin(dict_RB)]

dict_RA
rem_A = A[A['movie_no'].isin(dict_RA)]

# %%
# s_A = clean_dup_A['ltable_movie_no'].append(pd.Series(s_A))
# s_B = clean_dup_B['rtable_movie_no'].append(pd.Series(s_B))
rem_B
# Out:
#                     movie_name  movie_year movie_certificate movie_runtime  \
# 1961       the disaster artist        2017                 R   104 minutes
# 2611  the theory of everything        2014             PG-13   123 minutes
#
#      movie_genre  movie_score  movie_gross movie_director  \
# 1961      Comedy          NaN          NaN   James Franco
# 2611       Drama          NaN  $35,887,263    James Marsh
#
#                                                                                                movie_star  \
# 1961  James Franco, Seth Rogen, Dave Franco, Josh Hutcherson, Alison Brie, Zac Efron, Kate Upton, Jack...
# 2611  Eddie Redmayne, Felicity Jones, Emily Watson, Charlie Cox, David Thewlis, Simon McBurney, Maxine...
#
#                             movie_writer tomatoter audience
# 1961  Scott Neustadter, Michael H. Weber       91%      88%
# 2611                    Anthony McCarten       78%      84%

# %%
m_A = A[(A['movie_no'].isin(clean_dup_A['ltable_movie_no']))]
m_B = B[(B['movie_no'].isin(clean_dup_B['rtable_movie_no']))]

# %%
clean_dup_A.rename(columns={"ltable_movie_no": "movie_no"}, inplace = True)
clean_dup_B.rename(columns={"rtable_movie_no": "movie_no"}, inplace = True)

m_B = pd.merge(m_B, clean_dup_B[['_id', 'movie_no']], how = 'left', on = 'movie_no')
m_A = pd.merge(m_A, clean_dup_A[['_id', 'movie_no']], how = 'left', on = 'movie_no')

# %%
m_F = pd.merge(m_A[['_id','movie_no', 'movie_name', 'movie_year', 'movie_certificate', 'movie_runtime', 
                   'movie_genre', 'movie_score', 'movie_gross', 'movie_director', 'movie_star']],
               m_B[['_id','movie_writer', 'tomatoter', 'audience']], how = 'left', on = '_id')

# %%
m_F
# Out:
#         _id  movie_no                                 movie_name  movie_year  \
# 0    301372         6             jumanji: welcome to the jungle        2017
# 1    133732        11                         the shape of water        2017
# 2     29027        13                             thor: ragnarok        2017
# 3     47783        17                             justice league        2017
# 4     92321        22                                       coco        2017
# 5     95187        23  three billboards outside ebbing, missouri        2017
# 6    583385        26                            pitch perfect 3        2017
# 7    356040        32               murder on the orient express        2017
# 8    491461        34                                  ferdinand        2017
# 9    227165        38                                   i, tonya        2017
# 10   660061        40                                 downsizing        2017
# 11    29273        41                       call me by your name        2017
# 12   258625        43                               wonder woman        2017
# 13   165213        44                              atomic blonde        2017
# 14   727184        45                          blade runner 2049        2017
# 15   291455        51                     spider-man: homecoming        2017
# 16   505415        54                                     wonder        2017
# 17   587304        55                                    get out        2017
# 18   574199        56                                  lady bird        2017
# 19    37764        57                                         it        2017
# 20   478203        58             guardians of the galaxy vol. 2        2017
# 21   417149        65                                 wind river        2017
# 22   339274        67                               darkest hour        2017
# 23   241071        71                               the outsider        2018
# 24   244230        73                                   deadpool        2016
# 25   567430        77                                    dunkirk        2017
# 26   293243        86                                baby driver        2017
# 27   138125        89                                   zootopia        2016
# 28   712530        92                 captain america: civil war        2016
# 29   236642        96                        the florida project        2017
# ..      ...       ...                                        ...         ...
# 683  507152      2806                                      siren        2016
# 684  435889      2810                                    pompeii        2014
# 685  715168      2811                                      tammy        2014
# 686  385755      2820                              let's be cops        2014
# 687   20365      2827                                suffragette        2015
# 688  569500      2831                   white bird in a blizzard        2014
# 689  421074      2834                            the crucifixion        2017
# 690  523826      2843                              shin godzilla        2016
# 691  190134      2848                                   the duel        2016
# 692  167388      2853   the spongebob movie: sponge out of water        2015
# 693  510791      2854                      most beautiful island        2017
# 694  225323      2869                 the other side of the door        2016
# 695  461835      2874                            playing it cool        2014
# 696  229168      2886                 far from the madding crowd        2015
# 697  257673      2896                            two night stand        2014
# 698  283244      2916                       deliver us from evil        2014
# 699    4410      2917                          love beats rhymes        2017
# 700  597615      2926                                     denial        2016
# 701  504568      2927                           the osiris child        2016
# 702  272439      2932                                     serena        2014
# 703  208649      2940                                        lbj        2016
# 704   99179      2945                        our kind of traitor        2016
# 705  472893      2946                               ride along 2        2016
# 706  755731      2952                                  the guest        2014
# 707  233891      2969                                    laggies        2014
# 708  573256      2990                             bleed for this        2016
# 709  313934      2991                             the polka king        2017
# 710  590702      2996                             wolf warrior 2        2017
# 711   50816      2997                                  get a job        2016
# 712   84822      2998                                     radius        2017
#
#     movie_certificate movie_runtime                   movie_genre  \
# 0               PG-13       119 min     Action, Adventure, Comedy
# 1                   R       123 min     Adventure, Drama, Fantasy
# 2               PG-13       130 min     Action, Adventure, Comedy
# 3               PG-13       120 min    Action, Adventure, Fantasy
# 4                  PG       105 min  Animation, Adventure, Comedy
# 5                   R       115 min                  Crime, Drama
# 6               PG-13        93 min                 Comedy, Music
# 7               PG-13       114 min         Crime, Drama, Mystery
# 8                  PG       108 min  Animation, Adventure, Comedy
# 9                   R       120 min      Biography, Comedy, Drama
# 10                  R       135 min         Comedy, Drama, Sci-Fi
# 11                  R       132 min                Drama, Romance
# 12              PG-13       141 min    Action, Adventure, Fantasy
# 13                  R       115 min     Action, Mystery, Thriller
# 14                  R       164 min        Drama, Mystery, Sci-Fi
# 15              PG-13       133 min     Action, Adventure, Sci-Fi
# 16                 PG       113 min                 Drama, Family
# 17                  R       104 min     Horror, Mystery, Thriller
# 18                  R        94 min                 Comedy, Drama
# 19                  R       135 min       Drama, Horror, Thriller
# 20              PG-13       136 min     Action, Adventure, Sci-Fi
# 21                  R       107 min         Crime, Drama, Mystery
# 22              PG-13       125 min     Biography, Drama, History
# 23              TV-MA       120 min         Crime, Drama, Mystery
# 24                  R       108 min     Action, Adventure, Comedy
# 25              PG-13       106 min        Action, Drama, History
# 26                  R       112 min          Action, Crime, Music
# 27                 PG       108 min  Animation, Adventure, Comedy
# 28              PG-13       147 min     Action, Adventure, Sci-Fi
# 29                  R       111 min                         Drama
# ..                ...           ...                           ...
# 683         Not Rated        82 min               Fantasy, Horror
# 684             PG-13       105 min      Action, Adventure, Drama
# 685                 R        97 min               Comedy, Romance
# 686                 R       104 min                 Comedy, Crime
# 687             PG-13       106 min     Biography, Drama, History
# 688                 R        91 min      Drama, Mystery, Thriller
# 689                 R        90 min     Horror, Mystery, Thriller
# 690         Not Rated       120 min      Action, Adventure, Drama
# 691                 R       110 min                Drama, Western
# 692                PG        92 min  Animation, Adventure, Comedy
# 693               NaN        80 min       Drama, Horror, Thriller
# 694                 R        96 min                        Horror
# 695                 R        94 min               Comedy, Romance
# 696             PG-13       119 min                Drama, Romance
# 697                 R        86 min               Comedy, Romance
# 698                 R       118 min      Action, Biography, Crime
# 699                 R       106 min                Drama, Musical
# 700             PG-13       109 min              Biography, Drama
# 701         Not Rated        95 min      Action, Adventure, Drama
# 702                 R       109 min                Drama, Romance
# 703                 R        98 min              Biography, Drama
# 704                 R       108 min        Crime, Drama, Thriller
# 705             PG-13       102 min                Action, Comedy
# 706                 R       100 min             Mystery, Thriller
# 707                 R        99 min        Comedy, Drama, Romance
# 708                 R       117 min       Biography, Drama, Sport
# 709             TV-14        95 min      Biography, Comedy, Drama
# 710         Not Rated       123 min       Action, Drama, Thriller
# 711                 R        83 min                        Comedy
# 712               NaN        93 min              Sci-Fi, Thriller
#
#      movie_score movie_gross                        movie_director  \
# 0            7.0    $403.11M                           Jake Kasdan
# 1            7.5     $63.54M                    Guillermo del Toro
# 2            7.9    $315.06M                         Taika Waititi
# 3            6.7    $229.02M                           Zack Snyder
# 4            8.5    $209.54M            Lee Unkrich, Adrian Molina
# 5            8.2     $54.25M                       Martin McDonagh
# 6            6.0    $104.90M                             Trish Sie
# 7            6.6    $102.83M                       Kenneth Branagh
# 8            6.7     $84.14M                       Carlos Saldanha
# 9            7.6     $29.95M                       Craig Gillespie
# 10           5.7     $24.45M                       Alexander Payne
# 11           8.0     $17.97M                       Luca Guadagnino
# 12           7.5    $412.56M                         Patty Jenkins
# 13           6.7     $51.57M                          David Leitch
# 14           8.1     $92.05M                      Denis Villeneuve
# 15           7.5    $334.20M                             Jon Watts
# 16           8.0    $132.42M                       Stephen Chbosky
# 17           7.7    $176.04M                          Jordan Peele
# 18           7.6     $48.95M                          Greta Gerwig
# 19           7.5    $327.48M                       Andy Muschietti
# 20           7.7    $389.81M                            James Gunn
# 21           7.8     $33.80M                       Taylor Sheridan
# 22           7.4     $56.44M                            Joe Wright
# 23           6.3         NaN                      Martin Zandvliet
# 24           8.0    $363.07M                            Tim Miller
# 25           8.0    $188.37M                     Christopher Nolan
# 26           7.7    $107.83M                          Edgar Wright
# 27           8.0    $341.27M  Byron Howard, Rich Moore, Jared Bush
# 28           7.8    $408.08M              Anthony Russo, Joe Russo
# 29           7.7      $5.90M                            Sean Baker
# ..           ...         ...                                   ...
# 683          5.4         NaN                          Gregg Bishop
# 684          5.5     $23.22M                    Paul W.S. Anderson
# 685          4.9     $84.53M                           Ben Falcone
# 686          6.5     $82.39M                       Luke Greenfield
# 687          6.9      $4.69M                          Sarah Gavron
# 688          6.4      $0.03M                           Gregg Araki
# 689          5.0         NaN                           Xavier Gens
# 690          6.7      $1.91M          Hideaki Anno, Shinji Higuchi
# 691          5.8         NaN                    Kieran Darcy-Smith
# 692          6.0    $162.99M           Paul Tibbitt, Mike Mitchell
# 693          5.6         NaN                           Ana Asensio
# 694          5.3      $2.99M                      Johannes Roberts
# 695          6.0         NaN                        Justin Reardon
# 696          7.1     $12.23M                     Thomas Vinterberg
# 697          6.4      $0.02M                           Max Nichols
# 698          6.2     $30.58M                      Scott Derrickson
# 13                                                                                      Kurt Johnstad
# 14                                                                     Michael Green, Hampton Fancher
# 15                                  John Francis Daley, Christopher Ford, Chris McKenna, Erik Sommers
# 16                                                        Jack Thorne, Steven Conrad, Stephen Chbosky
# 17                                                                                       Jordan Peele
# 18                                                                                       Greta Gerwig
# 19                                                   Chase Palmer, Cary Joji Fukunaga, Gary Dauberman
# 20                                                                                         James Gunn
# 21                                                                                    Taylor Sheridan
# 22                                                                                   Anthony McCarten
# 23                                                                                     Andrew Baldwin
# 24                                                                          Rhett Reese, Paul Wernick
# 25                                                                                  Christopher Nolan
# 26                                                                                       Edgar Wright
# 27                                                                          Jared Bush, Phil Johnston
# 28                                                                Christopher Markus, Stephen McFeely
# 29                                                                          Chris Bergoch, Sean Baker
# ..                                                                                                ...
# 683                                                                      Luke Piotrowski, Ben Collins
# 684  Janet Scott Batchelor, Michael Robert Johnson, Lee Batchelor, Janet Scott Batchler, Lee Batchler
# 685                                                                     Ben Falcone, Melissa McCarthy
# 686                                                                  Luke Greenfield, Nicholas Thomas
# 687                                                                                        Abi Morgan
# 688                                                                                       Gregg Araki
# 689                                                                                        Chad Hayes
# 690                                                                                      Hideaki Anno
# 691                                                                                         Matt Cook
# 692                                    Glenn Berger, Paul Tibbitt, Jonathan Aibel, Stephen Hillenburg
# 693                                                                                       Ana Asensio
# 694                                                                    Johannes Roberts, Ernest Riera
# 695                                                                       Chris Shafer, Paul Vicknair
# 696                                                                                    David Nicholls
# 697                                                                                       Mark Hammer
# 698                                                            Paul Harris Boardman, Scott Derrickson
# 699                                                                            Nicole Jefferson Asher
# 700                                                                                        David Hare
# 701                                                                        Shane Abbess, Brian Cachia
# 702                                                                                  Christopher Kyle
# 703                                                                                    Joey Hartstone
# 704                                                                      John Le Carré, Hossein Amini
# 705                                                            Greg Coolidge, Phil Hay, Matt Manfredi
# 706                                                                                     Simon Barrett
# 707                                                                                     Andrea Seigel
# 708                                                                                       Ben Younger
# 709                                                                   Maya Forbes, Wallace Wolodarsky
# 710                                                                         Jing Wu, Yi Liu, Qun Dong
# 711                                                                      Kyle Pennekamp, Scott Turpel
# 712                                                                 Caroline Labrèche, Steeve Léonard
#
#     tomatoter audience
# 0         76%      88%
# 1         92%      75%
# 2         92%      87%
# 3         40%      76%
# 4         97%      95%
# 5         92%      87%
# 6         32%      49%
# 7         57%      56%
# 8         71%      49%
# 9         90%      89%
# 10        51%      23%
# 11        95%      86%
# 12        92%      88%
# 13        77%      64%
# 14        87%      81%
# 15        92%      88%
# 16        85%      88%
# 17        99%      87%
# 18        99%      80%
# 19        85%      84%
# 20        83%      88%
# 21        87%      90%
# 22        85%      83%
# 23        22%      78%
# 24        83%      90%
# 25        92%      81%
# 26        93%      86%
# 27        98%      92%
# 28        91%      89%
# 29        95%      79%
# ..        ...      ...
# 683       71%      38%
# 684       28%      34%
# 685       24%      36%
# 686       18%      51%
# 687       72%      68%
# 688       55%      43%
# 689        0%      22%
# 690       83%      73%
# 691       26%      29%
# 692       80%      54%
# 693       94%      40%
# 694       37%      29%
# 695       15%      32%
# 696       85%      75%
# 697       40%      45%
# 698       29%      42%
# 699       50%      77%
# 700       83%      71%
# 701       61%      44%
# 702       16%      24%
# 703       54%      57%
# 704       72%      50%
# 705       13%      48%
# 706       89%      69%
# 707       66%      50%
# 708       70%      69%
# 709       59%      52%
# 710       70%      79%
# 711        5%      21%
# 712       91%      58%
#
# [713 rows x 14 columns]

# %%
m_Dl = tn[tn["_id"].isin(res)]
m_Dr = m_Dl.copy()
m_Dl.rename(columns={"ltable_movie_no": "movie_no"}, inplace = True)
m_Dr.rename(columns={"rtable_movie_no": "movie_no"}, inplace = True)

# %%
m_DA = A[(A['movie_no'].isin(s_A))]
m_DB = B[(B['movie_no'].isin(s_B))]

# %%
m_DB = pd.merge(m_DB, m_Dr[['_id', 'movie_no']], how = 'left', on = 'movie_no')
m_DA = pd.merge(m_DA, m_Dl[['_id', 'movie_no']], how = 'left', on = 'movie_no')

# %%
m_DF = pd.merge(m_DA[['_id','movie_no', 'movie_name', 'movie_year', 'movie_certificate', 'movie_runtime', 
                   'movie_genre', 'movie_score', 'movie_gross', 'movie_director', 'movie_star']],
               m_DB[['_id','movie_writer', 'tomatoter', 'audience']], how = 'left', on = '_id')

# %%
new_A = new_A.drop(['Unnamed: 0', 'movie_no'], axis = 1)
new_B = new_B.drop(['Unnamed: 0', 'movie_no'], axis = 1)
rem_A = rem_A.drop(['Unnamed: 0', 'movie_no'], axis = 1)
rem_B = rem_B.drop(['Unnamed: 0', 'movie_no'], axis = 1)
m_F = m_F.drop(['_id', 'movie_no'], axis=1)
m_DF = m_DF.drop(['_id', 'movie_no'], axis=1)

# %%
frames = [new_A, rem_A, new_B, rem_B, m_F, m_DF]

# %%
result = pd.concat(frames, ignore_index=True)

# %%
result
# Out:
#                                      movie_name  movie_year movie_certificate  \
# 0                              ready player one        2018             PG-13
# 1                        avengers: infinity war        2018               NaN
# 2                         pacific rim: uprising        2018             PG-13
# 3                                 black panther        2018             PG-13
# 4                                   tomb raider        2018             PG-13
# 5                               game over, man!        2018             TV-MA
# 6                          the greatest showman        2017                PG
# 7                                  annihilation        2018                 R
# 8                                 a quiet place        2018             PG-13
# 9                                  isle of dogs        2018             PG-13
# 10                                i kill giants        2017         Not Rated
# 11      star wars: episode viii - the last jedi        2017             PG-13
# 12                   all the money in the world        2017                 R
# 13                                   deadpool 2        2018               NaN
# 14                                  red sparrow        2018                 R
# 15                                  love, simon        2018             PG-13
# 16                           i can only imagine        2018                PG
# 17                            a wrinkle in time        2018                PG
# 18                                     terminal        2018               NaN
# 19                                       unsane        2018                 R
# 20                               captain marvel        2019               NaN
# 21                                 molly's game        2017                 R
# 22                        the spy who dumped me        2018               NaN
# 23          the house with a clock in its walls        2018               NaN
# 24                          x-men: dark phoenix        2019               NaN
# 25                                   game night        2018                 R
# 26                                  pacific rim        2013             PG-13
# 27                                    the titan        2018             TV-MA
# 28                                     blockers        2018                 R
# 29                              sherlock gnomes        2018                PG
# ...                                         ...         ...               ...
# 5217                            playing it cool        2014                 R
# 5218                 far from the madding crowd        2015             PG-13
# 5219                            two night stand        2014                 R
# 5220                       deliver us from evil        2014                 R
# 5221                          love beats rhymes        2017                 R
# 5222                                     denial        2016             PG-13
# 5223                           the osiris child        2016         Not Rated
# 5224                                     serena        2014                 R
# 5225                                        lbj        2016                 R
# 5226                        our kind of traitor        2016                 R
# 5227                               ride along 2        2016             PG-13
# 5228                                  the guest        2014                 R
# 5229                                    laggies        2014                 R
# 5230                             bleed for this        2016                 R
# 5231                             the polka king        2017             TV-14
# 5232                             wolf warrior 2        2017         Not Rated
# 5233                                  get a job        2016                 R
# 5234                                     radius        2017               NaN
# 5235                        the disaster artist        2017                 R
# 5236                   the theory of everything        2014             PG-13
# 5237                            the maze runner        2014             PG-13
# 5238             maze runner: the scorch trials        2015             PG-13
# 5239  the hobbit: the battle of the five armies        2014             PG-13
# 5240            the hunger games: catching fire        2013             PG-13
# 5241                        fifty shades darker        2017                 R
# 5242        the hobbit: the desolation of smaug        2013             PG-13
# 5243      the hunger games: mockingjay - part 2        2015             PG-13
# 5244                                    the bfg        2016                PG
# 5245      the hunger games: mockingjay - part 1        2014             PG-13
# 5246                              the institute        2017                 R
#
#      movie_runtime                   movie_genre  movie_score movie_gross  \
# 0          140 min     Action, Adventure, Sci-Fi          7.9     $68.35M
# 1          156 min    Action, Adventure, Fantasy          NaN         NaN
# 2          111 min     Action, Adventure, Sci-Fi          6.0     $49.21M
# 3          134 min     Action, Adventure, Sci-Fi          7.8    $655.62M
# 4          118 min             Action, Adventure          6.8     $52.73M
# 5          101 min                Action, Comedy          5.4         NaN
# 6          105 min     Biography, Drama, Musical          7.8    $172.49M
# 7          115 min     Adventure, Drama, Fantasy          7.1     $32.31M
# 8           90 min       Drama, Horror, Thriller          8.3         NaN
# 9          101 min  Animation, Adventure, Comedy          8.2      $7.16M
# 10         106 min      Drama, Fantasy, Thriller          6.6         NaN
# 11         152 min    Action, Adventure, Fantasy          7.4    $620.12M
# 12         132 min       Biography, Crime, Drama          7.0     $25.11M
# 13             NaN     Action, Adventure, Comedy          NaN         NaN
# 14         140 min      Drama, Mystery, Thriller          6.8     $45.96M
# 15         110 min        Comedy, Drama, Romance          8.1     $34.28M
# 16         110 min                 Drama, Family          7.6     $59.61M
# 17         109 min    Adventure, Family, Fantasy          4.2     $86.25M
# 18          90 min               Drama, Thriller          NaN         NaN
# 19          98 min              Horror, Thriller          6.8      $7.49M
# 20             NaN     Action, Adventure, Sci-Fi          NaN         NaN
# 21         140 min       Biography, Crime, Drama          7.5     $28.78M
# 22             NaN                Action, Comedy          NaN         NaN
# 23             NaN      Fantasy, Horror, Mystery          NaN         NaN
# 24             NaN     Action, Adventure, Sci-Fi          NaN         NaN
# 25         100 min        Comedy, Crime, Mystery          7.4     $65.98M
# 26         131 min     Action, Adventure, Sci-Fi          6.9    $101.80M
# 27          97 min                        Sci-Fi          5.0         NaN
# 28         102 min                        Comedy          6.3         NaN
# 29          86 min  Animation, Adventure, Comedy          4.7     $27.22M
# ...            ...                           ...          ...         ...
# 5217        94 min               Comedy, Romance          6.0         NaN
# 5218       119 min                Drama, Romance          7.1     $12.23M
# 5219        86 min               Comedy, Romance          6.4      $0.02M
# 5220       118 min      Action, Biography, Crime          6.2     $30.58M
# 5221       106 min                Drama, Musical          5.0         NaN
# 5222       109 min              Biography, Drama          6.6      $4.07M
# 5223        95 min      Action, Adventure, Drama          5.6         NaN
# 5224       109 min                Drama, Romance          5.4      $0.18M
# 5225        98 min              Biography, Drama          6.3      $2.47M
# 5226       108 min        Crime, Drama, Thriller          6.2      $3.15M
# 5227       102 min                Action, Comedy          5.9     $90.84M
# 5228       100 min             Mystery, Thriller          6.7      $0.32M
# 5229        99 min        Comedy, Drama, Romance          6.4      $0.44M
# 5230       117 min       Biography, Drama, Sport          6.8      $4.85M
# 5231        95 min      Biography, Comedy, Drama          5.9         NaN
# 5232       123 min       Action, Drama, Thriller          6.3      $2.72M
# 5233        83 min                        Comedy          5.3         NaN
# 5234        93 min              Sci-Fi, Thriller          6.2         NaN
# 5235       104 min      Biography, Comedy, Drama          7.6     $21.12M
# 5236       123 min     Biography, Drama, Romance          7.7     $35.89M
# 5237       113 min       Action, Mystery, Sci-Fi          6.8    $102.43M
# 5238       131 min      Action, Sci-Fi, Thriller          6.3     $81.67M
# 5239       144 min            Adventure, Fantasy          7.4    $255.12M
# 5240       146 min    Action, Adventure, Mystery          7.5    $424.67M
# 5241       118 min                Drama, Romance          4.6    $114.38M
# 5242       161 min            Adventure, Fantasy          7.9    $258.37M
# 5243       137 min     Action, Adventure, Sci-Fi          6.5    $281.72M
# 5244       117 min    Adventure, Family, Fantasy          6.4     $55.48M
# 5245       123 min     Action, Adventure, Sci-Fi          6.7    $337.14M
# 5246        90 min                      Thriller          4.1         NaN
#
#                               movie_director  \
# 0                           Steven Spielberg
# 1                   Anthony Russo, Joe Russo
# 2                         Steven S. DeKnight
# 3                               Ryan Coogler
# 4                                Roar Uthaug
# 5                             Kyle Newacheck
# 6                             Michael Gracey
# 7                               Alex Garland
# 8                             John Krasinski
# 9                               Wes Anderson
# 10                             Anders Walter
# 11                              Rian Johnson
# 12                              Ridley Scott
# 13                              David Leitch
# 14                          Francis Lawrence
# 15                             Greg Berlanti
# 16                   Andrew Erwin, Jon Erwin
# 17                              Ava DuVernay
# 18                              Vaughn Stein
# 19                         Steven Soderbergh
# 20                    Anna Boden, Ryan Fleck
# 21                              Aaron Sorkin
# 22                             Susanna Fogel
# 23                                  Eli Roth
# 24                             Simon Kinberg
# 25    John Francis Daley, Jonathan Goldstein
# 26                        Guillermo del Toro
# 27                              Lennart Ruff
# 28                                Kay Cannon
# 29                            John Stevenson
# ...                                      ...
# 5217                          Justin Reardon
# 5218                       Thomas Vinterberg
# 5219                             Max Nichols
# 5220                        Scott Derrickson
# ...                                                                           ...
# 5217                   Chris Evans, Michelle Monaghan, Topher Grace, Aubrey Plaza
# 5218           Carey Mulligan, Matthias Schoenaerts, Michael Sheen, Tom Sturridge
# 5219                       Miles Teller, Analeigh Tipton, Jessica Szohr, Kid Cudi
# 5220                              Eric Bana, Edgar Ramrez, Olivia Munn, Chris Coy
# 5221                         Common, Hana Mae Lee, Arjun Gupta, Lucien Laviscount
# 5222                     Rachel Weisz, Tom Wilkinson, Timothy Spall, Andrew Scott
# 5223                      Kellan Lutz, Daniel MacPherson, Isabel Lucas, Luke Ford
# 5224                    Bradley Cooper, Jennifer Lawrence, Rhys Ifans, Toby Jones
# 5225  Woody Harrelson, Michael Stahl-David, Richard Jenkins, Jennifer Jason Leigh
# 5226              Carlos Acosta, Radivoje Bukvic, Stellan Skarsgrd, Mariya Fomina
# 5227                           Ice Cube, Kevin Hart, Tika Sumpter, Benjamin Bratt
# 5228                   Dan Stevens, Sheila Kelley, Maika Monroe, Joel David Moore
# 5229                Keira Knightley, Chlo Grace Moretz, Sam Rockwell, Mark Webber
# 5230                        Miles Teller, Aaron Eckhart, Katey Sagal, Ciarn Hinds
# 5231                     Jack Black, Jenny Slate, Jason Schwartzman, Jacki Weaver
# 5232                                  Jing Wu, Frank Grillo, Celina Jade, Gang Wu
# 5233                  Miles Teller, Anna Kendrick, Bryan Cranston, Nicholas Braun
# 5234       Diego Klattenhoff, Charlotte Sullivan, Robert Borges, Andrea del Campo
# 5235                           James Franco, Dave Franco, Ari Graynor, Seth Rogen
# 5236                      Eddie Redmayne, Felicity Jones, Tom Prior, Sophie Perry
# 5237         Dylan O'Brien, Kaya Scodelario, Will Poulter, Thomas Brodie-Sangster
# 5238   Dylan O'Brien, Kaya Scodelario, Thomas Brodie-Sangster, Giancarlo Esposito
# 5239               Ian McKellen, Martin Freeman, Richard Armitage, Cate Blanchett
# 5240   Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Philip Seymour Hoffman
# 5241                   Dakota Johnson, Jamie Dornan, Eric Johnson, Eloise Mumford
# 5242                    Ian McKellen, Martin Freeman, Richard Armitage, Ken Stott
# 5243          Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody Harrelson
# 5244                Mark Rylance, Ruby Barnhill, Penelope Wilton, Jemaine Clement
# 5245          Jennifer Lawrence, Josh Hutcherson, Liam Hemsworth, Woody Harrelson
# 5246                 James Franco, Allie Gallerani, Tim Blake Nelson, Lori Singer
#
#                                                                         movie_writer  \
# 0                                                                                NaN
# 1                                                                                NaN
# 2                                                                                NaN
# 3                                                                                NaN
# 4                                                                                NaN
# 5                                                                                NaN
# 6                                                                                NaN
# 7                                                                                NaN
# 8                                                                                NaN
# 9                                                                                NaN
# 10                                                                               NaN
# 11                                                                               NaN
# 12                                                                               NaN
# 13                                                                               NaN
# 14                                                                               NaN
# 15                                                                               NaN
# 16                                                                               NaN
# 17                                                                               NaN
# 18                                                                               NaN
# 19                                                                               NaN
# 20                                                                               NaN
# 21                                                                               NaN
# 22                                                                               NaN
# 23                                                                               NaN
# 24                                                                               NaN
# 25                                                                               NaN
# 26                                                                               NaN
# 27                                                                               NaN
# 28                                                                               NaN
# 29                                                                               NaN
# ...                                                                              ...
# 5217                                                     Chris Shafer, Paul Vicknair
# 5218                                                                  David Nicholls
# 5219                                                                     Mark Hammer
# 5220                                          Paul Harris Boardman, Scott Derrickson
# 5221                                                          Nicole Jefferson Asher
# 5222                                                                      David Hare
# 5223                                                      Shane Abbess, Brian Cachia
# 5224                                                                Christopher Kyle
# 5225                                                                  Joey Hartstone
# 5226                                                    John Le Carré, Hossein Amini
# 5227                                          Greg Coolidge, Phil Hay, Matt Manfredi
# 5228                                                                   Simon Barrett
# 5229                                                                   Andrea Seigel
# 5230                                                                     Ben Younger
# 5231                                                 Maya Forbes, Wallace Wolodarsky
# 5232                                                       Jing Wu, Yi Liu, Qun Dong
# 5233                                                    Kyle Pennekamp, Scott Turpel
# 5234                                               Caroline Labrèche, Steeve Léonard
# 5235                                                          Adam Rager, Matt Rager
# 5236                                                      Nicole Perlman, James Gunn
# 5237                                 Noah Oppenheim, Grant Pierce Myers, T.S. Nowlin
# 5238                                                                     T.S. Nowlin
# 5239                                 Philippa Boyens, Guillermo del Toro, Fran Walsh
# 5240                                                       Danny Strong, Peter Craig
# 5241                                                                   Niall Leonard
# 5242  J.R.R. Tolkien, Fran Walsh, Guillermo del Toro, Peter Jackson, Philippa Boyens
# 5243                                      Danny Strong, Suzanne Collins, Peter Craig
# 5244                                                                Melissa Mathison
# 5245                                 Simon Beaufoy, Michael DeBruyn, Suzanne Collins
# 5246                                                               Pamela Romanowsky
#
#      tomatoter audience
# 0          NaN      NaN
# 1          NaN      NaN
# 2          NaN      NaN
# 3          NaN      NaN
# 4          NaN      NaN
# 5          NaN      NaN
# 6          NaN      NaN
# 7          NaN      NaN
# 8          NaN      NaN
# 9          NaN      NaN
# 10         NaN      NaN
# 11         NaN      NaN
# 12         NaN      NaN
# 13         NaN      NaN
# 14         NaN      NaN
# 15         NaN      NaN
# 16         NaN      NaN
# 17         NaN      NaN
# 18         NaN      NaN
# 19         NaN      NaN
# 20         NaN      NaN
# 21         NaN      NaN
# 22         NaN      NaN
# 23         NaN      NaN
# 24         NaN      NaN
# 25         NaN      NaN
# 26         NaN      NaN
# 27         NaN      NaN
# 28         NaN      NaN
# 29         NaN      NaN
# ...        ...      ...
# 5217       15%      32%
# 5218       85%      75%
# 5219       40%      45%
# 5220       29%      42%
# 5221       50%      77%
# 5222       83%      71%
# 5223       61%      44%
# 5224       16%      24%
# 5225       54%      57%
# 5226       72%      50%
# 5227       13%      48%
# 5228       89%      69%
# 5229       66%      50%
# 5230       70%      69%
# 5231       59%      52%
# 5232       70%      79%
# 5233        5%      21%
# 5234       91%      58%
# 5235        0%      15%
# 5236       91%      92%
# 5237       65%      68%
# 5238       46%      54%
# 5239       59%      75%
# 5240       66%      71%
# 5241       10%      48%
# 5242       74%      85%
# 5243       70%      66%
# 5244       75%      57%
# 5245       89%      89%
# 5246       21%      30%
#
# [5247 rows x 12 columns]

# %%
result.to_csv("merge_table.csv", encoding='utf-8')
